# %% [markdown]
# # Scatter Plots
#
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables (Cartio.com).
#
# In this part of our class, we will use surface area and Population Data for  Countries from Worldbank. As you can guess, Surface Area and Population will be our two variables.

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Read world bank Area Data
df_Area = pd.read_csv("data_files\Worldbank Country Area_v2.csv",delimiter="\t",index_col=0)

df_Area.ffill(inplace=True)

df_Area.tail()
# Out:
#       Aruba  Africa Eastern and Southern  Afghanistan  \
# 2021  180.0                  14845090.23     652230.0
# 2022  180.0                  14845090.23     652230.0
# 2023  180.0                  14845090.23     652230.0
# 2024  180.0                  14845090.23     652230.0
# 2025  180.0                  14845090.23     652230.0
#
#       Africa Western and Central     Angola  Albania  Andorra   Arab World  \
# 2021                   9045773.0  1246700.0  27400.0    470.0  13100559.00
# 2022                   9045773.0  1246700.0  27400.0    470.0  13096083.71
# 2023                   9045773.0  1246700.0  27400.0    470.0  13096083.71
# 2024                   9045773.0  1246700.0  27400.0    470.0  13096083.71
# 2025                   9045773.0  1246700.0  27400.0    470.0  13096083.71
#
#       United Arab Emirates  Argentina  ...  Virgin Islands (U.S.)  Viet Nam  \
# 2021               71020.0  2736690.0  ...                  350.0  313429.0
# 2022               71020.0  2736690.0  ...                  350.0  313429.0
# 2023               71020.0  2736690.0  ...                  350.0  313429.0
# 2024               71020.0  2736690.0  ...                  350.0  313429.0
# 2025               71020.0  2736690.0  ...                  350.0  313429.0
#
#       Vanuatu        World   Samoa  Kosovo  Yemen, Rep.  South Africa  \
# 2021  12190.0  129783069.3  2780.0     NaN     527970.0     1213090.0
# 2022  12190.0  129718826.2  2780.0     NaN     527970.0     1213090.0
# 2023  12190.0  129718826.2  2780.0     NaN     527970.0     1213090.0
# 2024  12190.0  129718826.2  2780.0     NaN     527970.0     1213090.0
# 2025  12190.0  129718826.2  2780.0     NaN     527970.0     1213090.0
#
#         Zambia  Zimbabwe
# 2021  743390.0  386850.0
# 2022  743390.0  386850.0
# 2023  743390.0  386850.0
# 2024  743390.0  386850.0
# 2025  743390.0  386850.0
#
# [5 rows x 266 columns]

# %%
#Read world bank Population Data
df_Pop = pd.read_csv("data_files\Worldbank Population Data_v2.csv",delimiter="\t", index_col=0)

df_Pop.tail()
# Out:
#          Aruba  Africa Eastern and Southern  Afghanistan  \
# 2021  107700.0                  713090928.0   40000412.0
# 2022  107310.0                  731821393.0   40578842.0
# 2023  107359.0                  750491370.0   41454761.0
# 2024  107995.0                  769280888.0   42647492.0
# 2025       NaN                          NaN          NaN
#
#       Africa Western and Central      Angola    Albania  Andorra   Arab World  \
# 2021                 485920997.0  34532429.0  2489762.0  78364.0  460646603.0
# 2022                 497387180.0  35635029.0  2451636.0  79705.0  471352066.0
# 2023                 509398589.0  36749906.0  2414095.0  80856.0  482105978.0
# 2024                 521764076.0  37885849.0  2377128.0  81938.0  492612632.0
# 2025                         NaN         NaN        NaN      NaN          NaN
#
#       United Arab Emirates   Argentina  ...  Virgin Islands (U.S.)  \
# 2021             9575152.0  45312281.0  ...               105870.0
# 2022            10074977.0  45407904.0  ...               105413.0
# 2023            10483751.0  45538401.0  ...               104917.0
# 2024            10986400.0  45696159.0  ...               104377.0
# 2025                   NaN         NaN  ...                    NaN
#
#          Viet Nam   Vanuatu         World     Samoa     Kosovo  Yemen, Rep.  \
# 2021   98935098.0  305868.0  7.920515e+09  213779.0  1786079.0   37140230.0
# 2022   99680655.0  313046.0  7.989545e+09  215261.0  1768096.0   38222876.0
# 2023  100352192.0  320409.0  8.064058e+09  216663.0  1682668.0   39390799.0
# 2024  100987686.0  327777.0  8.141809e+09  218019.0  1594353.0   40583164.0
# 2025          NaN       NaN           NaN       NaN        NaN          NaN
#
#       South Africa      Zambia    Zimbabwe
# 2021    61502603.0  19603607.0  15797210.0
# 2022    62378410.0  20152938.0  16069056.0
# 2023    63212384.0  20723965.0  16340822.0
# 2024    64007187.0  21314956.0  16634373.0
# 2025           NaN         NaN         NaN
#
# [5 rows x 266 columns]

# %%
y_values[y_values > 1000]
# Out:
# China                                           1408.975000
# East Asia & Pacific (excluding high income)     2141.122258
# Early-demographic dividend                      3552.278604
# East Asia & Pacific                             2388.319494
# Fragile and conflict affected situations        1081.767572
# High income                                     1417.841927
# IBRD only                                       4979.421568
# IDA & IBRD total                                6926.222113
# IDA total                                       1946.800545
# IDA only                                        1269.842894
# India                                           1450.935791
# Least developed countries: UN classification    1187.777591
# Lower middle income                             3120.980912
# Low & middle income                             6563.501708
# Late-demographic dividend                       2328.628339
# Middle income                                   5938.893610
# OECD members                                    1396.877448
# Pre-demographic dividend                        1105.951788
# Post-demographic dividend                       1128.377826
# South Asia                                      1677.384532
# Sub-Saharan Africa (excluding high income)      1158.863843
# Sub-Saharan Africa                              1291.044964
# East Asia & Pacific (IDA & IBRD countries)      2114.653077
# South Asia (IDA & IBRD)                         1677.384532
# Sub-Saharan Africa (IDA & IBRD countries)       1291.044964
# Upper middle income                             2817.912698
# World                                           8141.808945
# Name: 2024, dtype: float64

# %%
x_values = df_Area.loc[2024,:]/1000 # express in thousands of km2
y_values =  df_Pop.loc[2024,:]/1000000 #express in millions

plt.figure(dpi=130)

plt.scatter(x_values, y_values)

plt.xlabel("Surface Area")
plt.ylabel("Population")

plt.show()

# %%
#List of Some Euroasian countries 
Countries = ["Belgium", "Bulgaria", "Germany","Denmark","Spain","Finland","France","United Kingdom",
             "Italy","Netherlands","Norway", "Poland", "Portugal","Sweden","Turkiye","Ukraine"]


#let's get 2018 surface area and population data for these countries
x_values = df_Area.loc[2024,Countries]/1000 # express in thousands of km2
y_values =  df_Pop.loc[2024,Countries]/1000000 #express in millions

#create scatter plot
plt.figure(dpi=130)
plt.scatter(x_values,y_values, marker = "s", c = "green", s = 15)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")

plt.legend(Countries)

plt.show()

# %% [markdown]
# ### Using Different Marker Styles and Colors
#
# **marker styles:** https://matplotlib.org/api/markers_api.html#module-matplotlib.markers
#
# **color codes:**
# **b:** blue
# **g:** green
# **r:** red
# **c:** cyan
# **m:** magenta
# **y:** yellow
# **k:** black
# **w:** white

# %%
#create scatter plot
plt.figure(dpi=150)

#Triangular marker
plt.scatter(x_values,y_values, marker = "v", c = "m", s = 15)

plt.legend(Countries)

#Red Square marker
#plt.scatter(x_values,y_values, marker='s', color='#449EA1')

#Black Mercedes marker
#plt.scatter(x_values,y_values, marker='2', color='k')

plt.show()

# %%
x_values["Turkey"]
# Out:
# 769.63

# %%
y_values["Turkey"]
# Out:
# 83.429615

# %%
plt.figure(dpi=150)

for country in Countries:
    plt.scatter(x_values[country], y_values[country])


plt.legend(Countries, loc = "lower center", bbox_to_anchor= (0.5 , 1.06), ncol = 4, fontsize = 8)

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")
plt.show()

# %% [markdown]
# ### Figure Annotation
#
# As we can see in the above plots, countries to which each data point belong to is not shown. Which makes plots harder to read. We may want to add a small explanataion next to some or all data points in similar situations. We can achieve this by using ```pyplot.annotate()```

# %%
x_values["Belgium"]
# Out:
# 30.28

# %%
import pycountry

# %%
# !conda install conda-forge::pycountry
# Out:
# ^C

# %%
#create scatter plot
plt.figure(dpi=130)

plt.scatter(x_values,y_values, c = "green")

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    if country == "Turkey":
        country_obj = pycountry.countries.get(name="Türkiye")
    else:
        country_obj = pycountry.countries.get(name=country)
    plt.annotate(country_obj.alpha_3, (x_values[country],y_values[country]), 
                fontsize = 8,
                textcoords = "offset pixels",
                xytext = (5,5)) 

#plt.annotate("Small \nCountries",(70,10),fontsize = 8,
 #            horizontalalignment = "center",
  #           textcoords = "offset pixels",
   #          xytext = (30,70),
    #         bbox = dict(boxstyle = "round", alpha = 0.5),
     #        arrowprops = {"arrowstyle": "-|>"} )

    
plt.show()

# %% [markdown]
# ### Annotation offset and arrow styles
#
# **Arrow styles and other parameters:** https://matplotlib.org/3.2.2/api/text_api.html#matplotlib.text.Text

# %% [markdown]
# ### Use different colors within the same data series
#
# if we supply parameter *c* (an array of integers) to scatter plot. Each integer will be mapped to a color in the current colormap. Then each data point will have the next color in line.

# %%
colors
# Out:
# array([102, 250, 103, 178, 211,  48, 254, 223, 224, 228, 163,  57, 118,
#        141, 190,  52], dtype=int32)

# %%
#create random numbers for random colors 
colors = np.random.randint(0,256,len(Countries))

#colors = np.arange(0,256, 16)

colors2 = ["#449EA1" , "#9EC633", "#C633C4", "#7d3808" , "#bb78d7", "#b44757","#92822b" , 
           "#331f6e", "#34a688","#bbfc48" , "#6a0c28", "#161b0a","#a7776a" , 
           "#08f932", "#d1510a", "#f3ba16"]

colors3 = y_values # nüfus bilgisi

#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values, c = colors3, cmap="viridis")

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")

for country in Countries:
    #country_obj = pycountry.countries.get(name=country)
    plt.annotate(country[0:3], (x_values[country],y_values[country]),
                 xytext=(8,8),
                 textcoords = 'offset pixels',
                 fontsize= 5
                 )

plt.colorbar(label = "Population (in millions)") # label = "Population (in millions)"
    
plt.show()

# %%
#Read world bank GDP Data
df_GDP = pd.read_csv("data_files\Worldbank GDP Data.csv",index_col=0)

#Fill missing values with 0 
df_GDP = df_GDP.fillna(0)

#express in billions of dollars
df_GDP = df_GDP /1000000000

df_GDP.tail()
# Out:
#          Aruba  Afghanistan      Angola    Albania   Andorra  Arab World  \
# Year
# 2015  2.919553    19.907111  116.194000  11.386846  2.789870     2529.69
# 2016  2.965922    19.362642  101.124000  11.861201  2.896679     2463.43
# 2017  3.056425    20.191760  122.124000  13.019693  3.000181     2513.49
# 2018  0.000000    19.484385  101.353000  15.147021  3.218316     2772.02
# 2019  0.000000    19.101354   94.635416  15.278077  3.154058     2815.41
#
#       United Arab Emirates  Argentina    Armenia  American Samoa  ...  \
# Year                                                              ...
# 2015               358.135    594.749  10.553338           0.661  ...
# 2016               357.045    557.531  10.546135           0.652  ...
# 2017               385.606    642.696  11.527459           0.602  ...
# 2018               422.215    519.872  12.457942           0.636  ...
# 2019               421.142    449.663  13.672802           0.000  ...
#
#       Virgin Islands (U.S.)  Vietnam   Vanuatu    World     Samoa    Kosovo  \
# Year
# 2015                  3.748  193.241  0.759690  75198.8  0.788307  6.442916
# 2016                  3.863  205.276  0.804333  76335.8  0.799376  6.719172
# 2017                  3.855  223.780  0.880044  81229.2  0.831904  7.245707
# 2018                  0.000  245.214  0.906050  86409.0  0.820492  7.942962
# 2019                  0.000  261.921  0.917059  87751.5  0.850655  7.926108
#
#       Yemen, Rep.  South Africa     Zambia   Zimbabwe
# Year
# 2015    36.976205       317.621  21.243347  19.963121
# 2016    28.084676       296.357  20.954762  20.548678
# 2017    24.561328       349.554  25.868142  22.040902
# 2018    27.591262       368.289  27.005239  24.311560
# 2019     0.000000       351.432  23.064722  21.440759
#
# [5 rows x 264 columns]

# %%
#get 2019 GDP for relevant countries

gdps= df_GDP.loc[2019,Countries]

gdps
# Out:
# Belgium            529.60700
# Bulgaria            67.92718
# Germany           3845.63000
# Denmark            348.07800
# Spain             1394.12000
# Finland            268.76100
# France            2715.52000
# United Kingdom    2827.11000
# Italy             2001.24000
# Netherlands        909.07000
# Norway             403.33600
# Poland             592.16400
# Portugal           237.68600
# Sweden             530.83300
# Turkey             754.41200
# Ukraine            153.78100
# Name: 2019, dtype: float64

# %%
#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values, c = gdps, cmap = "inferno")

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")

plt.colorbar(label = "Gross Domestic Product")

for country in Countries:
    #country_obj = pycountry.countries.get(name=country)
    plt.annotate(country[0:3], (x_values[country],y_values[country]),
                 xytext=(8,8),
                 textcoords = 'offset pixels',
                 fontsize= 5
                 )
    
    
plt.show()

# %% [markdown]
# ### Use different colormaps
#
# This applies to all kinds of figures we can create with Matplotlib. We can change to colormap of the figure by changing *cmap* parameter.
#
# **full list of colormaps:** https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
#create random numbers for random colors 
np.random.seed(250)
colors = np.random.randint(0,256,len(Countries))

#create scatter plot
plt.figure(dpi=150)

plt.scatter(x_values,y_values,c = gdps, cmap= 'autumn')
#plt.scatter(x_values,y_values,c = np.arange(0,16),cmap= 'tab20')
#plt.scatter(x_values,y_values,c = colors,cmap= 'Greens')

plt.colorbar()

plt.title("Population - Surface Area")
plt.xlabel("Surface Area (x 1000 km2)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country[0:3], (x_values[country],y_values[country]),
                 xytext=(8,8),
                 textcoords = 'offset pixels',
                 fontsize= 5
                 )
    
plt.show()

# %% [markdown]
# ### Adding a third dimension to a Scatter Plot (i.e. Create a Bubble Plot)
#
# We can create a bubble plot by supplying individual marker sizes to each data point. We can achieve this by setting parameter *s* for scatter plot equal to an array containing the size of individual data points.
#
# Let's make the size of each data point proportional to the corresponding country's GDP. Hence the third dimension in our figure will be the GDP of the country.

# %%
#create scatter plot
plt.figure(dpi=150)

#add size information here
#add alpha to make circles transparent
plt.scatter(x_values,y_values,c = gdps, s=gdps, alpha = 0.4, cmap = "inferno")

plt.title("Population - Surface Area (Bubble Size ~ GDP)")
plt.xlabel("Surface Area (x 1000 $km^{2}$)")
plt.ylabel("Population (in millions)")


for country in Countries:
    plt.annotate(country, (x_values[country],y_values[country]),
                 horizontalalignment = "center",
                 verticalalignment = "center",
                 fontsize= 5)
    

#change limits to make sure all bubbles fit in the graph
plt.xlim(-50,850)
plt.ylim(-5,100)

plt.colorbar(label = "Gross Domestic Product")

plt.savefig("BubblePlot.PNG", dpi = 400)    
    
plt.show()

# %% [markdown]
# # Practice Question
#
# Pay attention to the dataset given below:

# %%
df_PerCapita = pd.read_excel("data_files\gdpPerCapita.xlsx")
df_PerCapita
# Out:
#                 country continent  year  lifeExp       pop     gdpPercap  \
# 0           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 1               Albania    Europe  2007   76.423   3600523   5937.029526
# 2               Algeria    Africa  2007   72.301  33333216   6223.367465
# 3                Angola    Africa  2007   42.731  12420476   4797.231267
# 4             Argentina  Americas  2007   75.320  40301927  12779.379640
# ..                  ...       ...   ...      ...       ...           ...
# 137             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 138  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 139         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 140              Zambia    Africa  2007   42.384  11746035   1271.211593
# 141            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#     iso_alpha  iso_num
# 0         AFG        4
# 1         ALB        8
# 2         DZA       12
# 3         AGO       24
# 4         ARG       32
# ..        ...      ...
# 137       VNM      704
# 138       PSE      275
# 139       YEM      887
# 140       ZMB      894
# 141       ZWE      716
#
# [142 rows x 8 columns]

# %% [markdown]
# Recreate the figure below for 30 countries randomly selected from the dataset above. Use log scale for gdp per capita.
# ![Practice 5](images\practice5.png)

# %%
numCountries = 30

plt.figure(dpi=150)

df = df_PerCapita.sample(numCountries, random_state=15).reset_index(drop=True)
df.set_index("country", inplace=True)
np.random.seed(10)
colors = np.random.randint(0,100,numCountries)
#TODO: Implement here

# %%
df
# Out:
#                  continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# country
# Austria             Europe  2007   79.829     8199783  36126.492700       AUT
# Namibia             Africa  2007   52.906     2055080   4811.060429       NAM
# Norway              Europe  2007   80.196     4627926  49357.190170       NOR
# Kenya               Africa  2007   54.110    35610177   1463.249282       KEN
# Mozambique          Africa  2007   42.082    19951656    823.685621       MOZ
# New Zealand        Oceania  2007   80.204     4115771  25185.009110       NZL
# Mexico            Americas  2007   76.195   108700891  11977.574960       MEX
# Saudi Arabia          Asia  2007   72.777    27601038  21654.831940       SAU
# South Africa        Africa  2007   49.339    43997828   9269.657808       ZAF
# Peru              Americas  2007   71.421    28674757   7408.905561       PER
# Ghana               Africa  2007   60.022    22873338   1327.608910       GHA
# Sweden              Europe  2007   80.884     9031088  33859.748350       SWE
# Cote d'Ivoire       Africa  2007   48.328    18013409   1544.750112       CIV
# Colombia          Americas  2007   72.889    44227550   7006.580419       COL
# Iceland             Europe  2007   81.757      301931  36180.789190       ISL
# Australia          Oceania  2007   81.235    20434176  34435.367440       AUS
# Hong Kong, China      Asia  2007   82.208     6980412  39724.978670       HKG
# Niger               Africa  2007   56.867    12894865    619.676892       NER
# Mauritius           Africa  2007   72.801     1250882  10956.991120       MUS
# Lesotho             Africa  2007   42.592     2012649   1569.331442       LSO
# Afghanistan           Asia  2007   43.828    31889923    974.580338       AFG
# Uruguay           Americas  2007   76.384     3447496  10611.462990       URY
# Jordan                Asia  2007   72.535     6053193   4519.461171       JOR
# India                 Asia  2007   64.698  1110396331   2452.210407       IND
# Canada            Americas  2007   80.653    33390141  36319.235010       CAN
# Belgium             Europe  2007   79.441    10392226  33692.605080       BEL
# Nicaragua         Americas  2007   72.899     5675356   2749.320965       NIC
# Congo, Dem. Rep.    Africa  2007   46.462    64606759    277.551859       COD
# Portugal            Europe  2007   78.098    10642836  20509.647770       PRT
# Somalia             Africa  2007   48.159     9118773    926.141068       SOM
#
#                   iso_num
# country
# Austria                40
# Namibia               516
# Norway                578
# Kenya                 404
# Mozambique            508
# New Zealand           554
# Mexico                484
# Saudi Arabia          682
# South Africa          710
# Peru                  604
# Ghana                 288
# Sweden                752
# Cote d'Ivoire         384
# Colombia              170
# Iceland               352
# Australia              36
# Hong Kong, China      344
# Niger                 562
# Mauritius             480
# Lesotho               426
# Afghanistan             4
# Uruguay               858
# Jordan                400
# India                 356
# Canada                124
# Belgium                56
# Nicaragua             558
# Congo, Dem. Rep.      180
# Portugal              620
# Somalia               706
